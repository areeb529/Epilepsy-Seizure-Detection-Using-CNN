# %%
import numpy as  np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('EpilepticSeizure.csv')
df
# Out:
#           Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  \
# 0      X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17
# 1      X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164
# 2         X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57
# 3       X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82
# 4       X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4
# ...           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 11495  X22.V1.114  -22  -22  -23  -26  -36  -42  -45  -42  -45  ...    15
# 11496  X19.V1.354  -47  -11   28   77  141  211  246  240  193  ...   -65
# 11497    X8.V1.28   14    6  -13  -16   10   26   27   -9    4  ...   -65
# 11498  X10.V1.932  -40  -25   -9  -12   -2   12    7   19   22  ...   121
# 11499  X16.V1.210   29   41   57   72   74   62   54   43   31  ...   -59
#
#        X171  X172  X173  X174  X175  X176  X177  X178  y
# ...

# %%
df=df.drop('Unnamed',axis='columns')
df
# Out:
#         X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  \
# 0      135  190  229  223  192  125   55   -9  -33  -38  ...   -17   -15
# 1      386  382  356  331  320  315  307  272  244  232  ...   164   150
# 2      -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    57    64
# 3     -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -82   -81
# 4       -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     4     2
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 11495  -22  -22  -23  -26  -36  -42  -45  -42  -45  -49  ...    15    16
# 11496  -47  -11   28   77  141  211  246  240  193  136  ...   -65   -33
# 11497   14    6  -13  -16   10   26   27   -9    4   14  ...   -65   -48
# 11498  -40  -25   -9  -12   -2   12    7   19   22   29  ...   121   135
# 11499   29   41   57   72   74   62   54   43   31   23  ...   -59   -25
#
#        X172  X173  X174  X175  X176  X177  X178  y
# ...

# %%
dict={1:0,2:1,3:1,4:2,5:2}
df.y=df.y.map(dict)
df.y
# Out:
# 0        2
# 1        0
# 2        2
# 3        2
# 4        2
#         ..
# 11495    1
# 11496    0
# 11497    2
# 11498    1
# 11499    2
# Name: y, Length: 11500, dtype: int64

# %%
df
# Out:
#         X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  \
# 0      135  190  229  223  192  125   55   -9  -33  -38  ...   -17   -15
# 1      386  382  356  331  320  315  307  272  244  232  ...   164   150
# 2      -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    57    64
# 3     -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -82   -81
# 4       -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     4     2
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 11495  -22  -22  -23  -26  -36  -42  -45  -42  -45  -49  ...    15    16
# 11496  -47  -11   28   77  141  211  246  240  193  136  ...   -65   -33
# 11497   14    6  -13  -16   10   26   27   -9    4   14  ...   -65   -48
# 11498  -40  -25   -9  -12   -2   12    7   19   22   29  ...   121   135
# 11499   29   41   57   72   74   62   54   43   31   23  ...   -59   -25
#
#        X172  X173  X174  X175  X176  X177  X178  y
# ...

# %%
df.y.value_counts()
# Out:
# 1    4600
# 2    4600
# 0    2300
# Name: y, dtype: int64

# %%
x=df.drop('y',axis='columns')
y=df.y

# %%
x
# Out:
#         X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X169  X170  \
# 0      135  190  229  223  192  125   55   -9  -33  -38  ...     8   -17
# 1      386  382  356  331  320  315  307  272  244  232  ...   168   164
# 2      -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    29    57
# 3     -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -80   -82
# 4       -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...    10     4
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 11495  -22  -22  -23  -26  -36  -42  -45  -42  -45  -49  ...    20    15
# 11496  -47  -11   28   77  141  211  246  240  193  136  ...   -94   -65
# 11497   14    6  -13  -16   10   26   27   -9    4   14  ...   -42   -65
# 11498  -40  -25   -9  -12   -2   12    7   19   22   29  ...   114   121
# 11499   29   41   57   72   74   62   54   43   31   23  ...   -94   -59
#
#        X171  X172  X173  X174  X175  X176  X177  X178
# ...

# %%
y
# Out:
# 0        2
# 1        0
# 2        2
# 3        2
# 4        2
#         ..
# 11495    1
# 11496    0
# 11497    2
# 11498    1
# 11499    2
# Name: y, Length: 11500, dtype: int64

# %%
x.shape
# Out:
# (11500, 178)

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=scale.fit_transform(x)

# %%
x.max()
# Out:
# 13.35274750446462

# %%
x.min()
# Out:
# -11.764377127274233

# %%
import keras

# %%
from keras.utils import to_categorical
y=to_categorical(y)
y
# Out:
# array([[0., 0., 1.],
#        [1., 0., 0.],
#        [0., 0., 1.],
#        ...,
#        [0., 0., 1.],
#        [0., 1., 0.],
#        [0., 0., 1.]], dtype=float32)

# %%
y.max()
# Out:
# 1.0

# %%
y.min()
# Out:
# 0.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=10,test_size=0.3)

# %%
x_train.shape
# Out:
# (8050, 178)

# %%
x_test.shape
# Out:
# (3450, 178)

# %%
import numpy as np
x_train=x_train.reshape(8050,178,1)
x_test=x_test.reshape(3450,178,1)
x_train.shape , x_test.shape
# Out:
# ((8050, 178, 1), (3450, 178, 1))

# %%
import tensorflow as tf
from tensorflow import keras

# %%
cnn=keras.Sequential([
    #LAYER 1
    keras.layers.Conv1D(filters=32 , kernel_size=3, activation='relu', input_shape=(178,1)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling1D(2),
    
    
    #LAYER 2
    keras.layers.Conv1D(filters=64 , kernel_size=3, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling1D(2),
    
    #LAYER 3
    keras.layers.Conv1D(filters=128 , kernel_size=3, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling1D(2),

    keras.layers.Flatten(),
    
    keras.layers.Dense(30,activation='relu'),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(3,activation='softmax')
])

# %%
cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_3 (Conv1D)            (None, 176, 32)           128
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 176, 32)           128
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 88, 32)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 86, 64)            6208
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 86, 64)            256
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 43, 64)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 41, 128)           24704
# ...

# %%
cnn.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
hist=cnn.fit(x_train, y_train , epochs=30,validation_split=0.2,verbose=1)
# Out:
# Epoch 1/30
# 202/202 [==============================] - 4s 20ms/step - loss: 0.4445 - accuracy: 0.8264 - val_loss: 2.4275 - val_accuracy: 0.5012
# Epoch 2/30
# 202/202 [==============================] - 4s 20ms/step - loss: 0.2495 - accuracy: 0.9026 - val_loss: 1.9981 - val_accuracy: 0.6199
# Epoch 3/30
# 202/202 [==============================] - 4s 17ms/step - loss: 0.2161 - accuracy: 0.9214 - val_loss: 0.7294 - val_accuracy: 0.7801
# Epoch 4/30
# 202/202 [==============================] - 4s 18ms/step - loss: 0.1663 - accuracy: 0.9340 - val_loss: 0.2001 - val_accuracy: 0.9342
# Epoch 5/30
# 202/202 [==============================] - 4s 18ms/step - loss: 0.1417 - accuracy: 0.9480 - val_loss: 0.3018 - val_accuracy: 0.8988
# Epoch 6/30
# 202/202 [==============================] - 4s 18ms/step - loss: 0.1188 - accuracy: 0.9579 - val_loss: 0.1947 - val_accuracy: 0.9342
# Epoch 7/30
# ...

# %%
cnn.evaluate(x_test,y_test)
# Out:
# 108/108 [==============================] - 1s 5ms/step - loss: 0.7090 - accuracy: 0.8870
# [0.708980917930603, 0.886956512928009]

# %%
y_pred=cnn.predict(x_test)

# %%
y_pred
# Out:
# array([[1.6699340e-13, 1.0000000e+00, 7.0116677e-13],
#        [9.8185618e-12, 1.0000000e+00, 3.3343986e-15],
#        [5.1790696e-08, 1.3989727e-02, 9.8601019e-01],
#        ...,
#        [1.4854026e-10, 1.0000000e+00, 6.5701326e-15],
#        [5.7601212e-11, 1.4260771e-05, 9.9998569e-01],
#        [1.0000000e+00, 2.2805884e-09, 3.5634087e-15]], dtype=float32)

# %%
y_test_class=[np.argmax(val) for val in y_test]
y_pred_class=[np.argmax(val) for val in y_pred]

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm=confusion_matrix(y_test_class,y_pred_class)
print(cm)
# Out:
# [[ 637   46    5]
#  [   9 1362    9]
#  [   1  320 1061]]

# %%
plt.figure(figsize=(10,8))
sns.heatmap(cm,annot=True,fmt='d')
plt.plot()
# Out:
# []

# %%
print(classification_report(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95       688
#            1       0.79      0.99      0.88      1380
#            2       0.99      0.77      0.86      1382
#
#     accuracy                           0.89      3450
#    macro avg       0.92      0.89      0.90      3450
# weighted avg       0.91      0.89      0.89      3450
